# %% [markdown]
# # Test Easy Exp

# %%
import sys
from copy import deepcopy

# %%
project_folder = "../"
sys.path.insert(0, project_folder)
print(sys.path) # view the path and verify
# Out:
# ['../', '/Users/federicosiciliano/Desktop/Py_utils/easy_lightning_development/easy_exp/ntb', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/federicosiciliano/Library/Python/3.11/lib/python/site-packages', '/opt/homebrew/lib/python3.11/site-packages', '/opt/homebrew/lib/python3.11/site-packages/Easy_Lightning-0.0.1-py3.11.egg']

# %%
import easy_exp

# %% [markdown]
# ## Configuration loading

# %%
cfg = easy_exp.cfg.load_configuration()

# %%
type(cfg)
# Out:
# easy_exp.cfg.ConfigObject

# %%
type(cfg["app1"]), type(cfg["__exp__"])
# Out:
# (dict, dict)

# %%
cfg["__exp__"]
# Out:
# {'name': 'prova',
#  'project_folder': '../',
#  'key_len': 16,
#  'key_prefix': '',
#  '__imports__': ['numpy as np',
#   {'name': 'pandas', 'fromlist': ['DataFrame']},
#   'multiprocessing'],
#  '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#  '__nosave__': {'app2.foo_str': None,
#   'app2.foo_int2': None,
#   'app2.app3.foo_int1': None,
#   'app1.app_glob1_2': None},
#  '__sweep__': {'parameters': {'app1.foo_sweep1': {'default': 3,
#     'values': [1, 2, 3, 4, 5]},
#    'app1.foo_sweep2': {'default': 3, 'min': 1, 'max': 5},
#    'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#    'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#    'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#     'min': 0.1234,
#     'max': 5.6789},
#    'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}},
#   'method': 'random'}}

# %%
cfg["app1"]["foo_parse2"]
# Out:
# array([1, 2, 3])

# %%
cfg["app1.foo_parse2"]
# Out:
# array([1, 2, 3])

# %%
cfg["app3.foo_str"] = "abc"

# %%
cfg["app3.foo_str"],cfg["app3"]["foo_str"]
# Out:
# ('abc', 'abc')

# %%
cfg["app1.foo_sweep1"]
# Out:
# 3

# %%
cfg["__exp__"]["__sweep__"]
# Out:
# {'parameters': {'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#   'app1.foo_sweep2': {'default': 3, 'min': 1, 'max': 5},
#   'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#   'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#   'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#    'min': 0.1234,
#    'max': 5.6789},
#   'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}},
#  'method': 'random'}

# %% [markdown]
# ## Experiment

# %%
cfg, exp_cfg = easy_exp.exp.separate_exp_cfg(cfg) # Drop __exp__ key cause it doesn't define an experiment's parameters

# %% [markdown]
# ### Experiment ids

# %%
print(easy_exp.exp.generate_random_id())
print(easy_exp.exp.generate_random_id(key_prefix="B-"))
print(easy_exp.exp.generate_random_id(key_len=8))
print(easy_exp.exp.generate_random_id(key_len=4,key_prefix="FS"))
# Out:
# IVGgiNrKy5QfR6S7
# B-qUHEtHK5qc4PdtuZ
# OwqotA85
# FSri5d

# %%
import string
import numpy as np
poss_chars = len(string.ascii_letters + string.digits) #62
default_k = 16
default_poss_keys = poss_chars ** default_k
print("Default number of possible keys: 10","^",np.log10(float(default_poss_keys)))
# Out:
# Default number of possible keys: 10 ^ 28.678267031972062

# %% [markdown]
# ### Hashing

# %%
#The only solution, is save each numpy array / pandas DF / else in the configuration as their own experiment, having a certain experiment ID
numpy_key = "app1.foo_parse2"
np_to_save_elsewhere = cfg[numpy_key]
np_exp_id = 123 #easy_exp.exp.generate_random_id() #get numpy object experiment ID somehow
cfg[numpy_key] = np_exp_id #now cfg doesn't have the numpy array anymore

pandas_key = "app1.foo_parse3"
pd_to_save_elsewhere = cfg[pandas_key]
pd_exp_id = 42 #easy_exp.exp.generate_random_id() #get pandas object experiment ID somehow
cfg[pandas_key] = pd_exp_id #now cfg doesn't have the pandas DF anymore

# %%
easy_exp.exp.hash_config(cfg)
# Out:
# '298a9057447450466ec0fec7a66f81c4'

# %%
cfg
# Out:
# {'app1': {'foo_str': 'string_value',
#   'foo_int': 123,
#   'foo_float': 1.23,
#   'foo_none': None,
#   'foo_list1': [123, '456', 789.0],
#   'foo_list2': [123, '456'],
#   'foo_ref1': 'string_value',
#   'foo_ref2': 'string_value',
#   'foo_parse1': ['a', 'b', 'c'],
#   'foo_parse2': 123,
#   'foo_parse3': 42,
#   'foo_parse4': 8,
#   'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#   'foo_sweep1': 3,
#   'foo_sweep2': 3,
#   'foo_sweep3': 'a',
#   'foo_sweep4': -3,
#   'app_glob': 'glob',
#   'app_glob2': 'glob2',
#   'app_glob1_2': 'glob1_2'},
#  'app2': {'app3': {'foo_int1': 123},
#   'foo_str': 'app2_foo',
#   'foo_int2': 123,
#   'foo_sweep': 'hey'},
#  'app3': {'foo_str': 'abc'}}

# %%
#cfg, exp_cfg = easy_exp.exp.separate_exp_cfg(cfg) # Drop __exp__ key cause it doesn't define an experiment's parameters
easy_exp.exp.get_experiment_id(cfg, exp_cfg)
# Out:
# (True, '8yvets7OTVlBViYT')

# %%
cfg["app2"]
# Out:
# {'app3': {'foo_int1': 123},
#  'foo_str': 'app2_foo',
#  'foo_int2': 123,
#  'foo_sweep': 'hey'}

# %% [markdown]
# ### Save experiments

# %%
cfg = easy_exp.exp.combine_exp_cfg(cfg, exp_cfg)

# %%
cfg["__exp__"]
# Out:
# {'name': 'prova',
#  'project_folder': '../',
#  'key_len': 16,
#  'key_prefix': '',
#  '__imports__': ['numpy as np',
#   {'name': 'pandas', 'fromlist': ['DataFrame']},
#   'multiprocessing'],
#  '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#  '__nosave__': {'app2.foo_str': None,
#   'app2.foo_int2': None,
#   'app2.app3.foo_int1': None,
#   'app1.app_glob1_2': None},
#  '__sweep__': {'parameters': {'app1.foo_sweep1': {'default': 3,
#     'values': [1, 2, 3, 4, 5]},
#    'app1.foo_sweep2': {'default': 3, 'min': 1, 'max': 5},
#    'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#    'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#    'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#     'min': 0.1234,
#     'max': 5.6789},
#    'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}},
#   'method': 'random'},
#  'hash': '22210c3deaff792a081a2c223d7564b8'}

# %%
easy_exp.exp.save_experiment(cfg)
# Save experiment can be called directly; it will set the experiment id directly

# %%
easy_exp.exp.get_experiment_id(cfg), easy_exp.exp.get_experiment_id(cfg)
# If the cfg exists, we get
# exp_found True
# Always the same experiment_id
# Out:
# ((True, '8yvets7OTVlBViYT'), (True, '8yvets7OTVlBViYT'))

# %%
cfg, exp_cfg = easy_exp.exp.separate_exp_cfg(cfg) # Drop __exp__ key cause it doesn't define an experiment's parameters

# %%
easy_exp.exp.get_experiment_id(cfg,exp_cfg), easy_exp.exp.get_experiment_id(cfg,exp_cfg) # Even if the cfg is divided, the result is the same
# Out:
# ((True, '8yvets7OTVlBViYT'), (True, '8yvets7OTVlBViYT'))

# %%
cfg["app5"] = 5

# %%
easy_exp.exp.get_experiment_id(cfg,exp_cfg), easy_exp.exp.get_experiment_id(cfg,exp_cfg) # If the cfg doesn't exist, we get a different experiment_id. Also, exp_found is False
# Out:
# ((True, 'K6jtVdbjgS4ky4xq'), (True, 'K6jtVdbjgS4ky4xq'))

# %%
easy_exp.exp.get_set_experiment_id(cfg,exp_cfg)
# Out:
# (True, 'K6jtVdbjgS4ky4xq')

# %%
exp_cfg["experiment_id"] # Now the experiment_id is saved inside exp_cfg
# Out:
# 'K6jtVdbjgS4ky4xq'

# %%
easy_exp.exp.get_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"]
# get_experiment_id is meant to search for the experiment in the file,
# so, if it doesn't find the cfg in the saved configurations,
# It will not set the exp_id inside exp_cfg
# Out:
# ((True, 'K6jtVdbjgS4ky4xq'), 'K6jtVdbjgS4ky4xq')

# %%
easy_exp.exp.get_set_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"]
# In the same way, get_set_experiment_id is meant to search for the experiment in the file,
# so, if it doesn't find the cfg in the saved configurations,
# it will not return the exp_id inside exp_cfg
# and will overwrite it
# Out:
# ((True, 'K6jtVdbjgS4ky4xq'), 'K6jtVdbjgS4ky4xq')

# %%
prev_cfg = deepcopy(cfg)

# %%
easy_exp.exp.save_experiment(cfg,exp_cfg)

# %%
prev_cfg == cfg # Check if cfg has been restored
# Out:
# True

# %%
# Now that the experiment is saved, we will always get the same experiment_id
easy_exp.exp.get_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"], easy_exp.exp.get_set_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"]
# Out:
# ((True, 'K6jtVdbjgS4ky4xq'),
#  'K6jtVdbjgS4ky4xq',
#  (True, 'K6jtVdbjgS4ky4xq'),
#  'K6jtVdbjgS4ky4xq')

# %%
# If we modify cfg so that is new, we get the same results as before
cfg["new_key"] = "kmasdkasm"
cfg["new_key2"] = {"abc":123}
easy_exp.exp.get_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"], easy_exp.exp.get_set_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"]
# Out:
# ((True, 'xS7ZYmJ428pPtH5g'),
#  'K6jtVdbjgS4ky4xq',
#  (True, 'xS7ZYmJ428pPtH5g'),
#  'xS7ZYmJ428pPtH5g')

# %%
easy_exp.exp.save_experiment(cfg,exp_cfg)

# %%
exp_cfg["__nosave__"] # Check nosave keys
# Out:
# {'app2.foo_str': None,
#  'app2.foo_int2': None,
#  'app2.app3.foo_int1': None,
#  'app1.app_glob1_2': None}

# %%
cfg["app2.foo_str"] = "modified" # Modify a nosave key

# %%
# If a nosave key is modified, the cfg will still match a saved one
easy_exp.exp.get_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"], easy_exp.exp.get_set_experiment_id(cfg,exp_cfg), exp_cfg["experiment_id"]
# Out:
# ((True, 'xS7ZYmJ428pPtH5g'),
#  'xS7ZYmJ428pPtH5g',
#  (True, 'xS7ZYmJ428pPtH5g'),
#  'xS7ZYmJ428pPtH5g')

# %%
cfg = easy_exp.exp.combine_exp_cfg(cfg,exp_cfg) # Combine the cfg with the exp_cfg

# %% [markdown]
# ### Load experiments

# %%
all_exps = easy_exp.exp.get_experiments(**exp_cfg)
all_exps
# Out:
# {'v8RM2ysSFdQ348dG': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'v8RM2ysSFdQ348dG',
#    'hash': '2efb2535b015311c43984c8453dd0016',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tJdBjGcUVbED9Hkj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tJdBjGcUVbED9Hkj',
#    'hash': '2d46e9c7f5e340bbee03c9d745cb2152',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PtoWbRh7hz4Cg55X': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PtoWbRh7hz4Cg55X',
#    'hash': 'bd6c1b3b2fcbc93022d3c2cfe06d1acb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qIHJOI8rrOmPdbC3': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qIHJOI8rrOmPdbC3',
#    'hash': '3456642e8d8f2de614b7479e0897aae0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1tIdm7UpLtQ90psD': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1tIdm7UpLtQ90psD',
#    'hash': 'c01bd96f1ed4cc52a816607ab1b7ece3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wD0Pz4qhtjgHcqEW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wD0Pz4qhtjgHcqEW',
#    'hash': 'd28663dea32291eb1eb060b315328a36',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5C7NwhSaOhDchpCY': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5C7NwhSaOhDchpCY',
#    'hash': 'b19341e71a06b52447831cc98d0f787c',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GqIGgCZyLWjYBNjc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GqIGgCZyLWjYBNjc',
#    'hash': 'a917a51610d6708fe454b8b75d9b0e42',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'NBeOnSumDROaKNdW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'NBeOnSumDROaKNdW',
#    'hash': '7fdcde42949fdbe315c646292f288132',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a'},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '97DWW572YHSzqzSq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '97DWW572YHSzqzSq',
#    'hash': 'b4671bed9d528ddc28ca35d420a72394',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  's6SuSEYWQ4YRaEXu': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 's6SuSEYWQ4YRaEXu',
#    'hash': '28eb214b9ab25a143890407c5239e8b4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8F7BfrP6LVT9yqU0': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8F7BfrP6LVT9yqU0',
#    'hash': '6d551900a8d0fdd1aaec6872a0ff7fb4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'taploomJv7rEKOWw': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'taploomJv7rEKOWw',
#    'hash': '7083d243d35016f7c69123dd5ace3c40',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PGW3QKDGwwrNPQod': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PGW3QKDGwwrNPQod',
#    'hash': 'db5efbab46b215fea17b116ba2c78046',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'edpM2WTtxpVWoERk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'edpM2WTtxpVWoERk',
#    'hash': '6d19cdb345de9e61039344d78cc83b28',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'iJDB7pY4ceXcizxn': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'iJDB7pY4ceXcizxn',
#    'hash': 'f8f77e3ba898b0e25e354afbc39ddb89',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EUGNAqcOvUpyCIJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EUGNAqcOvUpyCIJz',
#    'hash': '7a62bac198de75590d8912c508853654',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wEI5nvLz5KBizr5N': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wEI5nvLz5KBizr5N',
#    'hash': '50256bcaff2fbf70a5c1df6d38bd9705',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'vobCvSwevxt5ZAuT': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'vobCvSwevxt5ZAuT',
#    'hash': '8d41dd61f026e9bbf1151cef4d3aa7b9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fazBDPfae7jPoSmA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fazBDPfae7jPoSmA',
#    'hash': '9c9a678d13ddb40335d2167f8c4cd755',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'pdlmWZTI879LD55y': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'pdlmWZTI879LD55y',
#    'hash': '80270a9766f7022a77d0a67d16b650c6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7kHX5R5lP7g7Lswc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7kHX5R5lP7g7Lswc',
#    'hash': '4061823289dded2be93381b4b1deb782',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'y88uVMPp5tckbN8l': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'y88uVMPp5tckbN8l',
#    'hash': '40a5aa33119a57376758b2aafaeb5dc6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'HT7GxsqKkPbDSGTI': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'HT7GxsqKkPbDSGTI',
#    'hash': 'e30eb4310f3e5dada85ea851f4baf68e',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '80ALTYlwH5IPgHAo': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '80ALTYlwH5IPgHAo',
#    'hash': '90324c6ab70ce4c7cb707c7111a347f6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'N2FrT1Vjsw1fjzEv': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'N2FrT1Vjsw1fjzEv',
#    'hash': '88a5f9949d373e29b43ce89dcce5bef3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'zNJfM6YwJqhLMx1b': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'zNJfM6YwJqhLMx1b',
#    'hash': 'ab9b2aa95aaeeb0d93ce039ea20b6936',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7AKpigk3FhUdhYRy': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7AKpigk3FhUdhYRy',
#    'hash': 'e0ade48dffa7fb59c03acbb4e36e4034',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'AszuyBIEVfvFxqQj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'AszuyBIEVfvFxqQj',
#    'hash': 'fcf1ba5fbef09a8b8826db09a7a826e0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
# ...
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'Zsk1Kqd0U8tiAGF2',
#    'hash': 'fceec58b29e2aa51ee6bb7b3a5eccdcb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EEEkxdTqGeXD3FmC': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EEEkxdTqGeXD3FmC',
#    'hash': 'b5711906f17b4c3a6f80430db52d54cf',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qYGghftLewfNUCJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qYGghftLewfNUCJz',
#    'hash': 'ecce345ceac510e34959a2d4e91dddf9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tZPkMXQiLn5Lqh6h': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tZPkMXQiLn5Lqh6h',
#    'hash': '02e30ad102d08bf994ef7e1f526b9c10',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'cpXNEtSTakytLXWO': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'cpXNEtSTakytLXWO',
#    'hash': '9af7f033d127aca9dfceeac7993ab9ad',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'm7ret4JLhWId5dhE': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'm7ret4JLhWId5dhE',
#    'hash': 'f78252d411ab02003766b8bd2796a39d',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GIIV1utFy97PXxta': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GIIV1utFy97PXxta',
#    'hash': '1efe4887841ea9a58cd21c6f6d21c312',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'ye99SJyVaifbbMPL': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'ye99SJyVaifbbMPL',
#    'hash': 'a0bcf7e4d2fdf120b506640f879bd691',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': {}},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'LntIBAq2pONkVBwq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'LntIBAq2pONkVBwq',
#    'hash': '488b1532bff7650dec837689839779d4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fo60lmUpKZH62vdX': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fo60lmUpKZH62vdX',
#    'hash': 'da3d3153a3cfc513faa79e18f07b3584',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  ...}

# %%
all_exps = easy_exp.exp.get_experiments(**exp_cfg, sub_cfg={"abc":123}) # If not setting check_type, nothing will be checked
all_exps
# Out:
# {'v8RM2ysSFdQ348dG': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'v8RM2ysSFdQ348dG',
#    'hash': '2efb2535b015311c43984c8453dd0016',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tJdBjGcUVbED9Hkj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tJdBjGcUVbED9Hkj',
#    'hash': '2d46e9c7f5e340bbee03c9d745cb2152',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PtoWbRh7hz4Cg55X': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PtoWbRh7hz4Cg55X',
#    'hash': 'bd6c1b3b2fcbc93022d3c2cfe06d1acb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qIHJOI8rrOmPdbC3': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qIHJOI8rrOmPdbC3',
#    'hash': '3456642e8d8f2de614b7479e0897aae0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1tIdm7UpLtQ90psD': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1tIdm7UpLtQ90psD',
#    'hash': 'c01bd96f1ed4cc52a816607ab1b7ece3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wD0Pz4qhtjgHcqEW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wD0Pz4qhtjgHcqEW',
#    'hash': 'd28663dea32291eb1eb060b315328a36',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5C7NwhSaOhDchpCY': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5C7NwhSaOhDchpCY',
#    'hash': 'b19341e71a06b52447831cc98d0f787c',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GqIGgCZyLWjYBNjc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GqIGgCZyLWjYBNjc',
#    'hash': 'a917a51610d6708fe454b8b75d9b0e42',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'NBeOnSumDROaKNdW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'NBeOnSumDROaKNdW',
#    'hash': '7fdcde42949fdbe315c646292f288132',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a'},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '97DWW572YHSzqzSq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '97DWW572YHSzqzSq',
#    'hash': 'b4671bed9d528ddc28ca35d420a72394',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  's6SuSEYWQ4YRaEXu': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 's6SuSEYWQ4YRaEXu',
#    'hash': '28eb214b9ab25a143890407c5239e8b4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8F7BfrP6LVT9yqU0': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8F7BfrP6LVT9yqU0',
#    'hash': '6d551900a8d0fdd1aaec6872a0ff7fb4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'taploomJv7rEKOWw': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'taploomJv7rEKOWw',
#    'hash': '7083d243d35016f7c69123dd5ace3c40',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PGW3QKDGwwrNPQod': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PGW3QKDGwwrNPQod',
#    'hash': 'db5efbab46b215fea17b116ba2c78046',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'edpM2WTtxpVWoERk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'edpM2WTtxpVWoERk',
#    'hash': '6d19cdb345de9e61039344d78cc83b28',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'iJDB7pY4ceXcizxn': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'iJDB7pY4ceXcizxn',
#    'hash': 'f8f77e3ba898b0e25e354afbc39ddb89',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EUGNAqcOvUpyCIJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EUGNAqcOvUpyCIJz',
#    'hash': '7a62bac198de75590d8912c508853654',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wEI5nvLz5KBizr5N': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wEI5nvLz5KBizr5N',
#    'hash': '50256bcaff2fbf70a5c1df6d38bd9705',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'vobCvSwevxt5ZAuT': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'vobCvSwevxt5ZAuT',
#    'hash': '8d41dd61f026e9bbf1151cef4d3aa7b9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fazBDPfae7jPoSmA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fazBDPfae7jPoSmA',
#    'hash': '9c9a678d13ddb40335d2167f8c4cd755',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'pdlmWZTI879LD55y': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'pdlmWZTI879LD55y',
#    'hash': '80270a9766f7022a77d0a67d16b650c6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7kHX5R5lP7g7Lswc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7kHX5R5lP7g7Lswc',
#    'hash': '4061823289dded2be93381b4b1deb782',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'y88uVMPp5tckbN8l': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'y88uVMPp5tckbN8l',
#    'hash': '40a5aa33119a57376758b2aafaeb5dc6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'HT7GxsqKkPbDSGTI': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'HT7GxsqKkPbDSGTI',
#    'hash': 'e30eb4310f3e5dada85ea851f4baf68e',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '80ALTYlwH5IPgHAo': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '80ALTYlwH5IPgHAo',
#    'hash': '90324c6ab70ce4c7cb707c7111a347f6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'N2FrT1Vjsw1fjzEv': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'N2FrT1Vjsw1fjzEv',
#    'hash': '88a5f9949d373e29b43ce89dcce5bef3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'zNJfM6YwJqhLMx1b': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'zNJfM6YwJqhLMx1b',
#    'hash': 'ab9b2aa95aaeeb0d93ce039ea20b6936',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7AKpigk3FhUdhYRy': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7AKpigk3FhUdhYRy',
#    'hash': 'e0ade48dffa7fb59c03acbb4e36e4034',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'AszuyBIEVfvFxqQj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'AszuyBIEVfvFxqQj',
#    'hash': 'fcf1ba5fbef09a8b8826db09a7a826e0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
# ...
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'Zsk1Kqd0U8tiAGF2',
#    'hash': 'fceec58b29e2aa51ee6bb7b3a5eccdcb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EEEkxdTqGeXD3FmC': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EEEkxdTqGeXD3FmC',
#    'hash': 'b5711906f17b4c3a6f80430db52d54cf',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qYGghftLewfNUCJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qYGghftLewfNUCJz',
#    'hash': 'ecce345ceac510e34959a2d4e91dddf9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tZPkMXQiLn5Lqh6h': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tZPkMXQiLn5Lqh6h',
#    'hash': '02e30ad102d08bf994ef7e1f526b9c10',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'cpXNEtSTakytLXWO': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'cpXNEtSTakytLXWO',
#    'hash': '9af7f033d127aca9dfceeac7993ab9ad',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'm7ret4JLhWId5dhE': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'm7ret4JLhWId5dhE',
#    'hash': 'f78252d411ab02003766b8bd2796a39d',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GIIV1utFy97PXxta': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GIIV1utFy97PXxta',
#    'hash': '1efe4887841ea9a58cd21c6f6d21c312',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'ye99SJyVaifbbMPL': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'ye99SJyVaifbbMPL',
#    'hash': 'a0bcf7e4d2fdf120b506640f879bd691',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': {}},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'LntIBAq2pONkVBwq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'LntIBAq2pONkVBwq',
#    'hash': '488b1532bff7650dec837689839779d4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fo60lmUpKZH62vdX': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fo60lmUpKZH62vdX',
#    'hash': 'da3d3153a3cfc513faa79e18f07b3584',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  ...}

# %%
# With contain, sub_cfg must be a "subset" of the dict
to_check = {'new_key': 'kmasdkasm','new_key2': {'abc': 123}}
all_exps = easy_exp.exp.get_experiments(**exp_cfg, sub_cfg = to_check, check_type="contain") # If not setting check_type, nothing will be checked
all_exps
# Out:
# {'v8RM2ysSFdQ348dG': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'v8RM2ysSFdQ348dG',
#    'hash': '2efb2535b015311c43984c8453dd0016',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tJdBjGcUVbED9Hkj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tJdBjGcUVbED9Hkj',
#    'hash': '2d46e9c7f5e340bbee03c9d745cb2152',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PtoWbRh7hz4Cg55X': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PtoWbRh7hz4Cg55X',
#    'hash': 'bd6c1b3b2fcbc93022d3c2cfe06d1acb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qIHJOI8rrOmPdbC3': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qIHJOI8rrOmPdbC3',
#    'hash': '3456642e8d8f2de614b7479e0897aae0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1tIdm7UpLtQ90psD': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1tIdm7UpLtQ90psD',
#    'hash': 'c01bd96f1ed4cc52a816607ab1b7ece3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wD0Pz4qhtjgHcqEW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wD0Pz4qhtjgHcqEW',
#    'hash': 'd28663dea32291eb1eb060b315328a36',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5C7NwhSaOhDchpCY': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5C7NwhSaOhDchpCY',
#    'hash': 'b19341e71a06b52447831cc98d0f787c',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GqIGgCZyLWjYBNjc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GqIGgCZyLWjYBNjc',
#    'hash': 'a917a51610d6708fe454b8b75d9b0e42',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'NBeOnSumDROaKNdW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'NBeOnSumDROaKNdW',
#    'hash': '7fdcde42949fdbe315c646292f288132',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a'},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '97DWW572YHSzqzSq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '97DWW572YHSzqzSq',
#    'hash': 'b4671bed9d528ddc28ca35d420a72394',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  's6SuSEYWQ4YRaEXu': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 's6SuSEYWQ4YRaEXu',
#    'hash': '28eb214b9ab25a143890407c5239e8b4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8F7BfrP6LVT9yqU0': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8F7BfrP6LVT9yqU0',
#    'hash': '6d551900a8d0fdd1aaec6872a0ff7fb4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'taploomJv7rEKOWw': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'taploomJv7rEKOWw',
#    'hash': '7083d243d35016f7c69123dd5ace3c40',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PGW3QKDGwwrNPQod': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PGW3QKDGwwrNPQod',
#    'hash': 'db5efbab46b215fea17b116ba2c78046',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'edpM2WTtxpVWoERk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'edpM2WTtxpVWoERk',
#    'hash': '6d19cdb345de9e61039344d78cc83b28',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'iJDB7pY4ceXcizxn': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'iJDB7pY4ceXcizxn',
#    'hash': 'f8f77e3ba898b0e25e354afbc39ddb89',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EUGNAqcOvUpyCIJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EUGNAqcOvUpyCIJz',
#    'hash': '7a62bac198de75590d8912c508853654',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wEI5nvLz5KBizr5N': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wEI5nvLz5KBizr5N',
#    'hash': '50256bcaff2fbf70a5c1df6d38bd9705',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'vobCvSwevxt5ZAuT': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'vobCvSwevxt5ZAuT',
#    'hash': '8d41dd61f026e9bbf1151cef4d3aa7b9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fazBDPfae7jPoSmA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fazBDPfae7jPoSmA',
#    'hash': '9c9a678d13ddb40335d2167f8c4cd755',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'pdlmWZTI879LD55y': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'pdlmWZTI879LD55y',
#    'hash': '80270a9766f7022a77d0a67d16b650c6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7kHX5R5lP7g7Lswc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7kHX5R5lP7g7Lswc',
#    'hash': '4061823289dded2be93381b4b1deb782',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'y88uVMPp5tckbN8l': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'y88uVMPp5tckbN8l',
#    'hash': '40a5aa33119a57376758b2aafaeb5dc6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'HT7GxsqKkPbDSGTI': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'HT7GxsqKkPbDSGTI',
#    'hash': 'e30eb4310f3e5dada85ea851f4baf68e',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '80ALTYlwH5IPgHAo': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '80ALTYlwH5IPgHAo',
#    'hash': '90324c6ab70ce4c7cb707c7111a347f6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'N2FrT1Vjsw1fjzEv': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'N2FrT1Vjsw1fjzEv',
#    'hash': '88a5f9949d373e29b43ce89dcce5bef3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'zNJfM6YwJqhLMx1b': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'zNJfM6YwJqhLMx1b',
#    'hash': 'ab9b2aa95aaeeb0d93ce039ea20b6936',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7AKpigk3FhUdhYRy': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7AKpigk3FhUdhYRy',
#    'hash': 'e0ade48dffa7fb59c03acbb4e36e4034',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'AszuyBIEVfvFxqQj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'AszuyBIEVfvFxqQj',
#    'hash': 'fcf1ba5fbef09a8b8826db09a7a826e0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
# ...
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GIIV1utFy97PXxta',
#    'hash': '1efe4887841ea9a58cd21c6f6d21c312',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'ye99SJyVaifbbMPL': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'ye99SJyVaifbbMPL',
#    'hash': 'a0bcf7e4d2fdf120b506640f879bd691',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': {}},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'LntIBAq2pONkVBwq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'LntIBAq2pONkVBwq',
#    'hash': '488b1532bff7650dec837689839779d4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fo60lmUpKZH62vdX': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fo60lmUpKZH62vdX',
#    'hash': 'da3d3153a3cfc513faa79e18f07b3584',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5pfJvEHdSVxNFlON': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5pfJvEHdSVxNFlON',
#    'hash': '61ad4e18cc37d9136ea5c669a3280c6b',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '0lOibAV2IRfg5JOk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '0lOibAV2IRfg5JOk',
#    'hash': '0cd4656eb2e16371f9c5a710c11114ad',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1ImU8jJexYWwwzWA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1ImU8jJexYWwwzWA',
#    'hash': 'da551fecb2a6e523ad0247e52ec072e4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8pANHQvfTo7NKaug': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8pANHQvfTo7NKaug',
#    'hash': 'b627618efb5457c55363d09d3f2e5588',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'h9qD9UbHlrnCUaBj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'h9qD9UbHlrnCUaBj',
#    'hash': '4e983165aad7387c160b5ea010de0c6b',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'hHvyjSBJfLeS5rvr': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'hHvyjSBJfLeS5rvr',
#    'hash': '13d25874c992a57bc942c167e4276397',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  ...}

# %%
#with match, sub_cfg must use relative keys
to_check = {'new_key2.abc': 123}
all_exps = easy_exp.exp.get_experiments(**exp_cfg, sub_cfg = to_check, check_type="match")
all_exps
# Out:
# {'v8RM2ysSFdQ348dG': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'v8RM2ysSFdQ348dG',
#    'hash': '2efb2535b015311c43984c8453dd0016',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'tJdBjGcUVbED9Hkj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'tJdBjGcUVbED9Hkj',
#    'hash': '2d46e9c7f5e340bbee03c9d745cb2152',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PtoWbRh7hz4Cg55X': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PtoWbRh7hz4Cg55X',
#    'hash': 'bd6c1b3b2fcbc93022d3c2cfe06d1acb',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'qIHJOI8rrOmPdbC3': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'qIHJOI8rrOmPdbC3',
#    'hash': '3456642e8d8f2de614b7479e0897aae0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1tIdm7UpLtQ90psD': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1tIdm7UpLtQ90psD',
#    'hash': 'c01bd96f1ed4cc52a816607ab1b7ece3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wD0Pz4qhtjgHcqEW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wD0Pz4qhtjgHcqEW',
#    'hash': 'd28663dea32291eb1eb060b315328a36',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5C7NwhSaOhDchpCY': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5C7NwhSaOhDchpCY',
#    'hash': 'b19341e71a06b52447831cc98d0f787c',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'GqIGgCZyLWjYBNjc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GqIGgCZyLWjYBNjc',
#    'hash': 'a917a51610d6708fe454b8b75d9b0e42',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'NBeOnSumDROaKNdW': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'NBeOnSumDROaKNdW',
#    'hash': '7fdcde42949fdbe315c646292f288132',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a'},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '97DWW572YHSzqzSq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '97DWW572YHSzqzSq',
#    'hash': 'b4671bed9d528ddc28ca35d420a72394',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  's6SuSEYWQ4YRaEXu': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 's6SuSEYWQ4YRaEXu',
#    'hash': '28eb214b9ab25a143890407c5239e8b4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8F7BfrP6LVT9yqU0': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8F7BfrP6LVT9yqU0',
#    'hash': '6d551900a8d0fdd1aaec6872a0ff7fb4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'taploomJv7rEKOWw': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'taploomJv7rEKOWw',
#    'hash': '7083d243d35016f7c69123dd5ace3c40',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'PGW3QKDGwwrNPQod': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'PGW3QKDGwwrNPQod',
#    'hash': 'db5efbab46b215fea17b116ba2c78046',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'edpM2WTtxpVWoERk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'edpM2WTtxpVWoERk',
#    'hash': '6d19cdb345de9e61039344d78cc83b28',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'iJDB7pY4ceXcizxn': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'iJDB7pY4ceXcizxn',
#    'hash': 'f8f77e3ba898b0e25e354afbc39ddb89',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'EUGNAqcOvUpyCIJz': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'EUGNAqcOvUpyCIJz',
#    'hash': '7a62bac198de75590d8912c508853654',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'wEI5nvLz5KBizr5N': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'wEI5nvLz5KBizr5N',
#    'hash': '50256bcaff2fbf70a5c1df6d38bd9705',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'vobCvSwevxt5ZAuT': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'vobCvSwevxt5ZAuT',
#    'hash': '8d41dd61f026e9bbf1151cef4d3aa7b9',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fazBDPfae7jPoSmA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fazBDPfae7jPoSmA',
#    'hash': '9c9a678d13ddb40335d2167f8c4cd755',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'pdlmWZTI879LD55y': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'pdlmWZTI879LD55y',
#    'hash': '80270a9766f7022a77d0a67d16b650c6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7kHX5R5lP7g7Lswc': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7kHX5R5lP7g7Lswc',
#    'hash': '4061823289dded2be93381b4b1deb782',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'y88uVMPp5tckbN8l': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'y88uVMPp5tckbN8l',
#    'hash': '40a5aa33119a57376758b2aafaeb5dc6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'HT7GxsqKkPbDSGTI': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'HT7GxsqKkPbDSGTI',
#    'hash': 'e30eb4310f3e5dada85ea851f4baf68e',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'b',
#    'foo_sweep4': -2},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '80ALTYlwH5IPgHAo': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '80ALTYlwH5IPgHAo',
#    'hash': '90324c6ab70ce4c7cb707c7111a347f6',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'N2FrT1Vjsw1fjzEv': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'N2FrT1Vjsw1fjzEv',
#    'hash': '88a5f9949d373e29b43ce89dcce5bef3',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'a',
#    'foo_sweep4': -1},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'zNJfM6YwJqhLMx1b': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'zNJfM6YwJqhLMx1b',
#    'hash': 'ab9b2aa95aaeeb0d93ce039ea20b6936',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '7AKpigk3FhUdhYRy': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '7AKpigk3FhUdhYRy',
#    'hash': 'e0ade48dffa7fb59c03acbb4e36e4034',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 3,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'AszuyBIEVfvFxqQj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'AszuyBIEVfvFxqQj',
#    'hash': 'fcf1ba5fbef09a8b8826db09a7a826e0',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
# ...
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'GIIV1utFy97PXxta',
#    'hash': '1efe4887841ea9a58cd21c6f6d21c312',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'ye99SJyVaifbbMPL': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'ye99SJyVaifbbMPL',
#    'hash': 'a0bcf7e4d2fdf120b506640f879bd691',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': {}},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'LntIBAq2pONkVBwq': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'LntIBAq2pONkVBwq',
#    'hash': '488b1532bff7650dec837689839779d4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'fo60lmUpKZH62vdX': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'fo60lmUpKZH62vdX',
#    'hash': 'da3d3153a3cfc513faa79e18f07b3584',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 5,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '5pfJvEHdSVxNFlON': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '5pfJvEHdSVxNFlON',
#    'hash': '61ad4e18cc37d9136ea5c669a3280c6b',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hey'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '0lOibAV2IRfg5JOk': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '0lOibAV2IRfg5JOk',
#    'hash': '0cd4656eb2e16371f9c5a710c11114ad',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd'},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '1ImU8jJexYWwwzWA': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '1ImU8jJexYWwwzWA',
#    'hash': 'da551fecb2a6e523ad0247e52ec072e4',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 4,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'e',
#    'foo_sweep4': -5},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  '8pANHQvfTo7NKaug': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': '8pANHQvfTo7NKaug',
#    'hash': 'b627618efb5457c55363d09d3f2e5588',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': -1000,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'd',
#    'foo_sweep4': -4},
#   'app2': {'app3': {}, 'foo_sweep': 'hello'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'h9qD9UbHlrnCUaBj': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'h9qD9UbHlrnCUaBj',
#    'hash': '4e983165aad7387c160b5ea010de0c6b',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 2,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  'hHvyjSBJfLeS5rvr': {'__exp__': {'__imports__': ['numpy as np',
#     {'fromlist': ['DataFrame'], 'name': 'pandas'},
#     'multiprocessing'],
#    '__nosave__': {'app1.app_glob1_2': None,
#     'app2.app3.foo_int1': None,
#     'app2.foo_int2': None,
#     'app2.foo_str': None},
#    '__sweep__': {'method': 'random',
#     'parameters': {'app1.app1_2.foo_sweep1_2': {'default': 1.2345,
#       'max': 5.6789,
#       'min': 0.1234},
#      'app1.foo_sweep1': {'default': 3, 'values': [1, 2, 3, 4, 5]},
#      'app1.foo_sweep2': {'default': 3, 'max': 5, 'min': 1},
#      'app1.foo_sweep3': {'default': 'a', 'values': ['a', 'b', 'c', 'd', 'e']},
#      'app1.foo_sweep4': {'default': -3, 'values': [-1, -2, -3, -4, -5]},
#      'app2.foo_sweep': {'default': 'hey', 'values': ['hi', 'hey', 'hello']}}},
#    '__wandb__': {'entity': 'sapienza_am', 'project': 'rec-posneg'},
#    'experiment_id': 'hHvyjSBJfLeS5rvr',
#    'hash': '13d25874c992a57bc942c167e4276397',
#    'key_len': 16,
#    'key_prefix': '',
#    'name': 'prova',
#    'project_folder': '../'},
#   'app1': {'app1_2': {'foo_str1_2': 'app2_foo', 'foo_sweep1_2': 1.2345},
#    'app_glob': 'glob',
#    'app_glob2': 'glob2',
#    'foo_float': 1.23,
#    'foo_int': 123,
#    'foo_list1': [123, '456', 789.0],
#    'foo_list2': [123, '456'],
#    'foo_none': None,
#    'foo_parse1': ['a', 'b', 'c'],
#    'foo_parse2': 123,
#    'foo_parse3': 42,
#    'foo_parse4': 8,
#    'foo_ref1': 'string_value',
#    'foo_ref2': 'string_value',
#    'foo_str': 'string_value',
#    'foo_sweep1': 1,
#    'foo_sweep2': 3,
#    'foo_sweep3': 'c',
#    'foo_sweep4': -3},
#   'app2': {'app3': {}, 'foo_sweep': 'hi'},
#   'app3': {'foo_str': 'abc'},
#   'app5': 5,
#   'new_key': 'kmasdkasm',
#   'new_key2': {'abc': 123}},
#  ...}

# %% [markdown]
# ### Sweep parameter

# %%
#If one parameter is an iterable of parameters to sweep, then use sweep. It will:
#1) cycle on every value in the
#2) set the value to the key
#3) return the value
#4) At the end of the cycle, restore the iterable as value to the key
sweep_keys = ['app1.foo_sweep1','app2.foo_sweep',('app1.foo_sweep3','app1.foo_sweep4')]
print([cfg[key] if isinstance(key,str) else [cfg[sub_key] for sub_key in key] for key in sweep_keys])
for param_value in cfg.sweep(*sweep_keys):
    if cfg['app2.foo_sweep'] == "hey":
        print("SHOULD BE -1000")
        cfg['app1.foo_sweep1'] = -1000
    print(param_value,"___",[cfg[key] if isinstance(key,str) else [cfg[sub_key] for sub_key in key] for key in sweep_keys])
    easy_exp.exp.get_set_experiment_id(cfg,exp_cfg),easy_exp.exp.save_experiment(cfg,exp_cfg)
print(cfg['app1.foo_sweep1'])
# Out:
# [3, 'hey', ['a', -3]]
# [1, 'hi', ('a', -1)] ___ [1, 'hi', ['a', -1]]
# [1, 'hi', ('b', -2)] ___ [1, 'hi', ['b', -2]]
# [1, 'hi', ('c', -3)] ___ [1, 'hi', ['c', -3]]
# [1, 'hi', ('d', -4)] ___ [1, 'hi', ['d', -4]]
# [1, 'hi', ('e', -5)] ___ [1, 'hi', ['e', -5]]
# SHOULD BE -1000
# [1, 'hey', ('a', -1)] ___ [-1000, 'hey', ['a', -1]]
# SHOULD BE -1000
# [1, 'hey', ('b', -2)] ___ [-1000, 'hey', ['b', -2]]
# SHOULD BE -1000
# [1, 'hey', ('c', -3)] ___ [-1000, 'hey', ['c', -3]]
# SHOULD BE -1000
# [1, 'hey', ('d', -4)] ___ [-1000, 'hey', ['d', -4]]
# SHOULD BE -1000
# [1, 'hey', ('e', -5)] ___ [-1000, 'hey', ['e', -5]]
# [1, 'hello', ('a', -1)] ___ [-1000, 'hello', ['a', -1]]
# [1, 'hello', ('b', -2)] ___ [-1000, 'hello', ['b', -2]]
# [1, 'hello', ('c', -3)] ___ [-1000, 'hello', ['c', -3]]
# [1, 'hello', ('d', -4)] ___ [-1000, 'hello', ['d', -4]]
# [1, 'hello', ('e', -5)] ___ [-1000, 'hello', ['e', -5]]
# [2, 'hi', ('a', -1)] ___ [2, 'hi', ['a', -1]]
# [2, 'hi', ('b', -2)] ___ [2, 'hi', ['b', -2]]
# [2, 'hi', ('c', -3)] ___ [2, 'hi', ['c', -3]]
# [2, 'hi', ('d', -4)] ___ [2, 'hi', ['d', -4]]
# [2, 'hi', ('e', -5)] ___ [2, 'hi', ['e', -5]]
# SHOULD BE -1000
# [2, 'hey', ('a', -1)] ___ [-1000, 'hey', ['a', -1]]
# SHOULD BE -1000
# [2, 'hey', ('b', -2)] ___ [-1000, 'hey', ['b', -2]]
# SHOULD BE -1000
# [2, 'hey', ('c', -3)] ___ [-1000, 'hey', ['c', -3]]
# SHOULD BE -1000
# [2, 'hey', ('d', -4)] ___ [-1000, 'hey', ['d', -4]]
# SHOULD BE -1000
# [2, 'hey', ('e', -5)] ___ [-1000, 'hey', ['e', -5]]
# [2, 'hello', ('a', -1)] ___ [-1000, 'hello', ['a', -1]]
# [2, 'hello', ('b', -2)] ___ [-1000, 'hello', ['b', -2]]
# [2, 'hello', ('c', -3)] ___ [-1000, 'hello', ['c', -3]]
# [2, 'hello', ('d', -4)] ___ [-1000, 'hello', ['d', -4]]
# [2, 'hello', ('e', -5)] ___ [-1000, 'hello', ['e', -5]]
# [3, 'hi', ('a', -1)] ___ [3, 'hi', ['a', -1]]
# [3, 'hi', ('b', -2)] ___ [3, 'hi', ['b', -2]]
# [3, 'hi', ('c', -3)] ___ [3, 'hi', ['c', -3]]
# [3, 'hi', ('d', -4)] ___ [3, 'hi', ['d', -4]]
# [3, 'hi', ('e', -5)] ___ [3, 'hi', ['e', -5]]
# SHOULD BE -1000
# [3, 'hey', ('a', -1)] ___ [-1000, 'hey', ['a', -1]]
# SHOULD BE -1000
# [3, 'hey', ('b', -2)] ___ [-1000, 'hey', ['b', -2]]
# SHOULD BE -1000
# [3, 'hey', ('c', -3)] ___ [-1000, 'hey', ['c', -3]]
# SHOULD BE -1000
# [3, 'hey', ('d', -4)] ___ [-1000, 'hey', ['d', -4]]
# SHOULD BE -1000
# [3, 'hey', ('e', -5)] ___ [-1000, 'hey', ['e', -5]]
# [3, 'hello', ('a', -1)] ___ [-1000, 'hello', ['a', -1]]
# [3, 'hello', ('b', -2)] ___ [-1000, 'hello', ['b', -2]]
# [3, 'hello', ('c', -3)] ___ [-1000, 'hello', ['c', -3]]
# [3, 'hello', ('d', -4)] ___ [-1000, 'hello', ['d', -4]]
# [3, 'hello', ('e', -5)] ___ [-1000, 'hello', ['e', -5]]
# [4, 'hi', ('a', -1)] ___ [4, 'hi', ['a', -1]]
# [4, 'hi', ('b', -2)] ___ [4, 'hi', ['b', -2]]
# [4, 'hi', ('c', -3)] ___ [4, 'hi', ['c', -3]]
# [4, 'hi', ('d', -4)] ___ [4, 'hi', ['d', -4]]
# [4, 'hi', ('e', -5)] ___ [4, 'hi', ['e', -5]]
# SHOULD BE -1000
# [4, 'hey', ('a', -1)] ___ [-1000, 'hey', ['a', -1]]
# SHOULD BE -1000
# [4, 'hey', ('b', -2)] ___ [-1000, 'hey', ['b', -2]]
# SHOULD BE -1000
# [4, 'hey', ('c', -3)] ___ [-1000, 'hey', ['c', -3]]
# SHOULD BE -1000
# [4, 'hey', ('d', -4)] ___ [-1000, 'hey', ['d', -4]]
# SHOULD BE -1000
# [4, 'hey', ('e', -5)] ___ [-1000, 'hey', ['e', -5]]
# [4, 'hello', ('a', -1)] ___ [-1000, 'hello', ['a', -1]]
# [4, 'hello', ('b', -2)] ___ [-1000, 'hello', ['b', -2]]
# [4, 'hello', ('c', -3)] ___ [-1000, 'hello', ['c', -3]]
# [4, 'hello', ('d', -4)] ___ [-1000, 'hello', ['d', -4]]
# [4, 'hello', ('e', -5)] ___ [-1000, 'hello', ['e', -5]]
# [5, 'hi', ('a', -1)] ___ [5, 'hi', ['a', -1]]
# [5, 'hi', ('b', -2)] ___ [5, 'hi', ['b', -2]]
# [5, 'hi', ('c', -3)] ___ [5, 'hi', ['c', -3]]
# [5, 'hi', ('d', -4)] ___ [5, 'hi', ['d', -4]]
# [5, 'hi', ('e', -5)] ___ [5, 'hi', ['e', -5]]
# SHOULD BE -1000
# [5, 'hey', ('a', -1)] ___ [-1000, 'hey', ['a', -1]]
# SHOULD BE -1000
# [5, 'hey', ('b', -2)] ___ [-1000, 'hey', ['b', -2]]
# SHOULD BE -1000
# [5, 'hey', ('c', -3)] ___ [-1000, 'hey', ['c', -3]]
# SHOULD BE -1000
# [5, 'hey', ('d', -4)] ___ [-1000, 'hey', ['d', -4]]
# SHOULD BE -1000
# [5, 'hey', ('e', -5)] ___ [-1000, 'hey', ['e', -5]]
# [5, 'hello', ('a', -1)] ___ [-1000, 'hello', ['a', -1]]
# [5, 'hello', ('b', -2)] ___ [-1000, 'hello', ['b', -2]]
# [5, 'hello', ('c', -3)] ___ [-1000, 'hello', ['c', -3]]
# [5, 'hello', ('d', -4)] ___ [-1000, 'hello', ['d', -4]]
# [5, 'hello', ('e', -5)] ___ [-1000, 'hello', ['e', -5]]
# 3

# %%
    cfg['app1.foo_sweep1'] = -1000

# %% [markdown]
# ## Sweep additions

# %%
cfg = easy_exp.cfg.load_configuration("config2")

# %%
cfg
# Out:
# {'__exp__': {'name': 'prova',
#   'project_folder': '../',
#   'key_len': 16,
#   'key_prefix': '',
#   '__nosave__': {},
#   '__sweep__': {'parameters': {}}},
#  'app1': {'+/app1_2': ['app1_2_file']},
#  '+app2': ['app2_file', 'app2bis_file']}

# %%
for value1 in cfg.sweep_additions("app2"):
    for value2 in cfg.sweep_additions("app1"):
        print(value2)
        print(cfg)
        print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [51], line 1
# ----> 1 for value1 in cfg.sweep_additions("app2"):
#       2     for value2 in cfg.sweep_additions("app1"):
#       3         print(value2)
#
# AttributeError: 'ConfigObject' object has no attribute 'sweep_additions'

# %%
cfg["app2"]

# %%
cfg

# %% [markdown]
# # Yaml loading times

# %%
import yaml, os, time

# %%
for i in range(10):
    with open(os.path.join("../out/exp",str(i)+".yaml"), 'w') as f:
        yaml.safe_dump(cfg["__exp__"],f)

# %%
start_time = time.time()

for cont in range(10001):
    with open(os.path.join("../out/exp",str(cont%10)+".yaml"), 'r') as f:
       cfg2 = yaml.safe_load(f)

       app = cfg==cfg2

    if cont in [1,10,100,1000,10000]:
        end_time = time.time()
        print(cont,"Time/read:",(end_time-start_time)/cont)
        print(cont,"Tot time:",(end_time-start_time))
        print()

# %% [markdown]
# ## Argparse

# %%
import argparse, numpy as np

# %%
parser = argparse.ArgumentParser(
                    prog = 'ProgramName',
                    description = 'What the program does',
                    epilog = 'Text at the bottom of help')

# %%
parser.add_argument(
    "--foo.foo", #name or flags - Either a name or a list of option strings, e.g. foo or -f, --foo.
    #optional arguments will be identified by the - prefix; remaining arguments will be assumed to be positional
    # action - The basic type of action to be taken when this argument is encountered at the command line.
# nargs - The number of command-line arguments that should be consumed.
# const - A constant value required by some action and nargs selections.
    default = [1,2,3], #np.ones((2,3))# default - The value produced if the argument is absent from the command line and if it is absent from the namespace object.
# type - The type to which the command-line argument should be converted.
# choices - A sequence of the allowable values for the argument.
# required - Whether or not the command-line option may be omitted (optionals only).
# help - A brief description of what the argument does.
# metavar - A name for the argument in usage messages.
# dest - The name of the attribute to be added to the object returned by parse_args().
    )

# %%
args = parser.parse_args(["--foo","1"])

# %%
eval("np.ones((1,2))")

# %% [markdown]
# ### Sweep

# %%
cfg = easy_exp.cfg.load_configuration()

# %%
easy_exp.wandb.wandb_sweep(cfg, lambda x: print(x))
